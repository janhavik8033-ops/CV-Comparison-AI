# %% [markdown]
# <a href="https://colab.research.google.com/github/janhavik8033-ops/CV-Comparison-AI/blob/main/ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pdfplumber

# %%
import re
import nltk
import pdfplumber
from google.colab import files
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop_words = set(stopwords.words('english'))

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z ]', '', text)
    words = text.split()
    words = [w for w in words if w not in stop_words]
    return " ".join(words)

# %%
stop_words = set(stopwords.words('english'))

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z ]', '', text)
    words = text.split()
    words = [w for w in words if w not in stop_words]
    return " ".join(words)

# %%
def read_file(uploaded, filename):
    if filename.endswith(".txt"):
        return uploaded[filename].decode("utf-8", errors="ignore")

    elif filename.endswith(".pdf"):
        text = ""
        with pdfplumber.open(filename) as pdf:
            for page in pdf.pages:
                text += page.extract_text() + " "
        return text

    else:
        raise ValueError("Only .txt or .pdf files are supported")

# %%
print("👋 Welcome to AI Resume Skill Gap Analyzer\n")

print("📄 Choose RESUME file (.txt or .pdf)")
resume_upload = files.upload()

print("\n📄 Choose JOB DESCRIPTION file (.txt or .pdf)")
job_upload = files.upload()

resume_file = list(resume_upload.keys())[0]
job_file = list(job_upload.keys())[0]

resume_text = read_file(resume_upload, resume_file)
job_text = read_file(job_upload, job_file)

print("\n✅ Files Loaded Successfully")
print("Resume:", resume_file)
print("Job Description:", job_file)
# Out:
# 👋 Welcome to AI Resume Skill Gap Analyzer
#
# 📄 Choose RESUME file (.txt or .pdf)
#      <input type="file" id="files-ae6c6451-2d3d-41c4-9204-d0d4b8adc3c0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ae6c6451-2d3d-41c4-9204-d0d4b8adc3c0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
clean_resume = clean_text(resume_text)
clean_job = clean_text(job_text)

vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform([clean_resume, clean_job])

similarity = cosine_similarity(vectors[0:1], vectors[1:2])[0][0]
matching_percentage = round(similarity * 100, 2)

resume_words = set(clean_resume.split())
job_words = set(clean_job.split())
missing_skills = job_words - resume_words

print("\n🎯 MATCHING RESULT")
print("Matching Percentage:", matching_percentage, "%")

print("\n❌ Missing Skills:")
for skill in missing_skills:
    print("-", skill)

print("\n💡 Improvement Suggestions:")
if matching_percentage < 40:
    print("• Resume is weakly matched. Add relevant skills.")
elif matching_percentage < 70:
    print("• Resume is moderately matched. Improve missing skills.")
else:
    print("• Resume is well matched. Minor improvements needed.")

print("• Skills to add:")
for skill in missing_skills:
    print("  -", skill)
# Out:
# 🎯 MATCHING RESULT
# Matching Percentage: 1.39 %
#
# ❌ Missing Skills:
# - nursing
# - fiveyear
# - professionalwith
# - undar
# - punamnursing
# - genralabout
# - housing
# - educationi
# - caring
# - strong
# - nursingth
# - knowlegelanguageenglishhindimarathigujrati
# - patient
# - doctor
# - personal
# - poonamahiregmailcompersonla
# - ahire
# - skills
# - schoolin
# - assistant
# - passoutcontactexperience
# - experienceskillsnursing
# - dedicated
# - pandesarapandesara
# - kunitamahal
# - assistantshivnagar
# - shivaji
# - providingsupport
# - patients
# - care
# - suratpersonal
# - managmentbasic
# - experience
# - doctors
# - chatrapati
#
# 💡 Improvement Suggestions:
# • Resume is weakly matched. Add relevant skills.
# • Skills to add:
#   - nursing
#   - fiveyear
#   - professionalwith
#   - undar
#   - punamnursing
#   - genralabout
#   - housing
#   - educationi
#   - caring
#   - strong
#   - nursingth
#   - knowlegelanguageenglishhindimarathigujrati
#   - patient
# ...
